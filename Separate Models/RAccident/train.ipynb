# %% [markdown]
# # Train

# %%
# !yolo task=detect mode=train model=yolov8l.pt imgsz=224 data="/content/drive/MyDrive/Collision/data.yaml" epochs=100 batch=124 name=/content/drive/MyDrive/Collision/final_training

# %%
from ultralytics import YOLO

model = YOLO()
model.train(data="D:/KAIF/RAccident/AccidentData/data.yaml", epochs=100)

# %% [markdown]
# # Detect Road Accidents

# %%
from ultralytics import YOLO
import cv2
import math
import datetime
import os
import csv
import time

cap = cv2.VideoCapture("D:/KAIF/RAccident/AccidentData/val/acc1.mp4")
model = YOLO('D:/KAIF/RAccident/RAccidents.pt')

# Class names
class_names = ['fire', 'minor_accident', 'moderate_accident', 'no_accident', 'severe_accident']

# Initialize variables
consecutive_frames = 0
confidence_threshold = 0.50
required_consecutive_frames = 5

new_width = 640
new_height = 480

log_dir = "logs"

while True:
    success, img = cap.read()

    if not success:
        break

    img = cv2.resize(img, (new_width, new_height))

    accident_detected = False

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            conf = box.conf[0]
            if conf >= confidence_threshold:
                class_index = int(box.cls[0])
                class_name = class_names[class_index]

                if class_name != 'no_accident':
                    accident_detected = True

                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                    w, h = x2 - x1, y2 - y1

                    conf = math.ceil((conf * 100)) / 100

                    info_text = f"{class_name} | {conf} "
                    cv2.putText(img, info_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
                    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)


                    current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    log_message = f"{class_name} | {cap.get(cv2.CAP_PROP_POS_FRAMES)} | {current_time} | {conf}"

                    current_year_month = datetime.datetime.now().strftime("%Y_%b")
                    current_day = datetime.datetime.now().strftime("%d_%m_%y")
                    log_filename = f"{current_day}_log.csv"
                    log_file_path = os.path.join(log_dir, current_year_month, log_filename)

                    os.makedirs(os.path.join(log_dir, current_year_month), exist_ok=True)

                    csv_header = ["Detection", "Frame Number", "Timestamp", "Confidence"]
                    csv_file_exists = os.path.exists(log_file_path)

                    if accident_detected and consecutive_frames >= required_consecutive_frames:
                        
                        with open(log_file_path, mode="a", newline="") as csvfile:
                            csv_writer = csv.writer(csvfile)

                            if not csv_file_exists:
                                csv_writer.writerow(csv_header)

                            csv_writer.writerow([class_name, cap.get(cv2.CAP_PROP_POS_FRAMES), current_time, conf])

                    print(log_message)

    if accident_detected:
        consecutive_frames += 1
    else:
        consecutive_frames = 0

    cv2.imshow("Image", img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 192x224 (no detections), 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 8.2ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.9ms
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 4.7ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.4ms
# Speed: 0.0ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.5ms
# Speed: 1.1ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 6.2ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.1ms
# Speed: 1.1ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.1ms
# Speed: 0.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 6.3ms
# Speed: 0.0ms preprocess, 6.3ms inference, 6.7ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 7.6ms
# Speed: 0.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.9ms
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 7.9ms
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.8ms
# Speed: 0.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 22.5ms
# Speed: 0.0ms preprocess, 22.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.7ms
# Speed: 0.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.4ms
# Speed: 0.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.0ms
# Speed: 1.1ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.7ms
# Speed: 0.0ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.6ms
# Speed: 0.0ms preprocess, 12.6ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 30.8ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 10.6ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 19.7ms
# Speed: 5.0ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 1 severe_accident, 10.0ms
# Speed: 1.3ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 9.2ms
# Speed: 5.4ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 1 severe_accident, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 3 no_accidents, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 3 no_accidents, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 9.8ms
# Speed: 1.0ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 7.6ms
# Speed: 0.0ms preprocess, 7.6ms inference, 4.5ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 minor_accident, 2 no_accidents, 8.6ms
# Speed: 0.0ms preprocess, 8.6ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 1 severe_accident, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 10.9ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 no_accidents, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 minor_accident, 1 no_accident, 1 severe_accident, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 9.5ms
# Speed: 0.7ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 1 severe_accident, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 13.2ms
# Speed: 0.8ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 0.1ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 minor_accident, 1 no_accident, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 9.7ms
# Speed: 4.4ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 minor_accident, 1 no_accident, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 7.8ms
# Speed: 0.0ms preprocess, 7.8ms inference, 5.1ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 19.9ms
# Speed: 0.0ms preprocess, 19.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 3.7ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 0.3ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 3 severe_accidents, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 181.0 | 2024-01-17 16:02:01 | 0.59
# 0: 192x224 1 severe_accident, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 182.0 | 2024-01-17 16:02:01 | 0.74
# 0: 192x224 1 severe_accident, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 183.0 | 2024-01-17 16:02:01 | 0.73
# 0: 192x224 1 severe_accident, 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 184.0 | 2024-01-17 16:02:01 | 0.54
# 0: 192x224 1 severe_accident, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 severe_accidents, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 2 severe_accidents, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 12.7ms
# Speed: 0.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 188.0 | 2024-01-17 16:02:01 | 0.6
# 0: 192x224 2 severe_accidents, 6.8ms
# Speed: 1.1ms preprocess, 6.8ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 189.0 | 2024-01-17 16:02:01 | 0.61
# 0: 192x224 2 severe_accidents, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 4.5ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 194.0 | 2024-01-17 16:02:01 | 0.66
# 0: 192x224 1 severe_accident, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 195.0 | 2024-01-17 16:02:01 | 0.54
# 0: 192x224 1 severe_accident, 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 196.0 | 2024-01-17 16:02:01 | 0.62
# 0: 192x224 1 minor_accident, 1 severe_accident, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 199.0 | 2024-01-17 16:02:01 | 0.58
# 0: 192x224 1 severe_accident, 12.1ms
# Speed: 0.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 7.3ms
# Speed: 0.0ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.7ms
# Speed: 1.1ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.3ms
# Speed: 1.4ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 6.7ms
# Speed: 0.9ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 severe_accident, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 223.0 | 2024-01-17 16:02:02 | 0.52
# 0: 192x224 1 severe_accident, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 1 no_accident, 1 severe_accident, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# severe_accident | 225.0 | 2024-01-17 16:02:02 | 0.54
# 0: 192x224 1 no_accident, 1 severe_accident, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 224)
#
# 0: 192x224 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 224)
